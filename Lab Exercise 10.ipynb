# %% [markdown]
# <p style="font-family: Arial; font-size:3em;color:black;"> Lab Exercise 10</p>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(5)  # creating pseudo-random numbers for reproducibility

# %%
# Let's consider the following A_orig matrix:

A_orig = np.array([[4, 2, 4, 5, 4, 2, 2], [4, 4, 3, 2, 2, 5, 4], [4, 1, 4, 7, 3, 6, 2], [8 ,1, 2, 0, 5, 0, 7], [4 , 5, 8, 7, 6, 2, 3]],dtype=float)
M, N = 5, 7
print (pd.DataFrame(A_orig).head())
# Out:
#      0    1    2    3    4    5    6
# 0  4.0  2.0  4.0  5.0  4.0  2.0  2.0
# 1  4.0  4.0  3.0  2.0  2.0  5.0  4.0
# 2  4.0  1.0  4.0  7.0  3.0  6.0  2.0
# 3  8.0  1.0  2.0  0.0  5.0  0.0  7.0
# 4  4.0  5.0  8.0  7.0  6.0  2.0  3.0

# %%
# Let's add some NaN(s) to  A_orig matrix

A = A_orig.copy()
A[3][1] = np.NaN
A[4][6] = np.NaN

A_df = pd.DataFrame(A)
print (A_df.head())
# Out:
#      0    1    2    3    4    5    6
# 0  4.0  2.0  4.0  5.0  4.0  2.0  2.0
# 1  4.0  4.0  3.0  2.0  2.0  5.0  4.0
# 2  4.0  1.0  4.0  7.0  3.0  6.0  2.0
# 3  8.0  NaN  2.0  0.0  5.0  0.0  7.0
# 4  4.0  5.0  8.0  7.0  6.0  2.0  NaN

# %%
# Fine tune K value such that the (average percentage) error for the 2 missing elements is minimum.
# Remember: this is an exercise where we have the actual values for missing elements. 
# In real-life scenarios missins elements are not known and you may need different metric(s)
# to assess the quality of your reconstructed matrix.
K = 7
P = np.abs(np.random.uniform(low=0, high=8, size=(M, K)))
Q = np.abs(np.random.uniform(low=0, high=8, size=(K, N)))
P = np.divide(P, K*P.max())
Q = np.divide(Q, K*Q.max())

# %%
def matrix_factorization(Rating_Matrix, P, Q, K, steps, alpha=0.001, beta=0.02):
    Q = Q.T
    for step in range(steps):
        for i in range(len(Rating_Matrix)):
            for j in range(len(Rating_Matrix[i])):
                if ~np.isnan(Rating_Matrix[i][j]):
                    eij = Rating_Matrix[i][j] - np.dot(P[i,:],Q[:,j])
                    for k in range(K):
                        P[i][k] = P[i][k] + alpha * (2 * eij * Q[k][j] - beta * P[i][k])
                        Q[k][j] = Q[k][j] + alpha * (2 * eij * P[i][k] - beta * Q[k][j])
        eRating_Matrix = np.dot(P,Q)
        e = 0
        for i in range(len(Rating_Matrix)):
            for j in range(len(Rating_Matrix[i])):
                if ~np.isnan(Rating_Matrix[i][j]):
                    e = e + pow(Rating_Matrix[i][j] - np.dot(P[i,:],Q[:,j]), 2)
                    for k in range(K):
                        e = e + (beta/2) * (pow(P[i][k],2) + pow(Q[k][j],2))
        print("Total error at step", step, "is", e)
        if e < 0.0001:
            break
    return P, Q.T

# %%
eP, eQ = matrix_factorization(A, P, Q.T, K, steps = 1000)
eA = np.matmul(eP, eQ.T)
print(A,'\n')
print(eA)
# Out:
# Total error at step 0 is 631.9838594982539
# Total error at step 1 is 631.0351476130569
# Total error at step 2 is 630.0043939977932
# Total error at step 3 is 628.8842628871097
# Total error at step 4 is 627.6668550052293
# Total error at step 5 is 626.3436720684451
# Total error at step 6 is 624.9055814242062
# Total error at step 7 is 623.342781374035
# Total error at step 8 is 621.6447678580311
# Total error at step 9 is 619.800303328986
# Total error at step 10 is 617.7973888154952
# Total error at step 11 is 615.6232403669837
# Total error at step 12 is 613.2642712896184
# Total error at step 13 is 610.7060818201224
# Total error at step 14 is 607.9334581429596
# Total error at step 15 is 604.9303829316151
# Total error at step 16 is 601.6800598815385
# Total error at step 17 is 598.1649549922514
# Total error at step 18 is 594.3668576378677
# Total error at step 19 is 590.2669647230126
# Total error at step 20 is 585.8459914349119
# Total error at step 21 is 581.0843122464669
# ...

# %%
#K=1

#Percentage Error = |Measured Value - True Value| / |True Value| x 100
#Caluclating error percentage of element 3,1 
k1_error_percentage_1 = abs(eA[3][1]-1)/1 *100
print(f"The error percentage of element (3,1) when k =1 is : {k1_error_percentage_1}")
#Caluclating error percentage of element 4,6
k1_error_percentage_2 = abs(eA[4][6]-3)/3 *100
print(f"The error percentage of element (4,6) when k =1 is : {k1_error_percentage_2}")
k1_average_percentage_error = (k1_error_percentage_1 + k1_error_percentage_2)/2
print(f"The average error percentage when k =1 is :{k1_average_percentage_error}")
# Out:
# The error percentage of element (3,1) when k =1 is : 183.2859111480571
# The error percentage of element (4,6) when k =1 is : 94.02881381166533
# The average error percentage when k =1 is :138.6573624798612

# %%
#K=2

#Percentage Error = |Measured Value - True Value| / |True Value| x 100
#Caluclating error percentage of element 3,1 
k2_error_percentage_1 = abs(eA[3][1]-1)/1 *100
print(f"The error percentage of element (3,1) when k =2 is : {k2_error_percentage_1}")
#Caluclating error percentage of element 4,6
k2_error_percentage_2 = abs(eA[4][6]-3)/3 *100
print(f"The error percentage of element (4,6) when k =2 is : {k2_error_percentage_2}")
k2_average_percentage_error = (k2_error_percentage_1 + k2_error_percentage_2)/2
print(f"The average error percentage when k =2 is :{k2_average_percentage_error}")
# Out:
# The error percentage of element (3,1) when k =2 is : 844.6095777023281
# The error percentage of element (4,6) when k =2 is : 48.14465976678433
# The average error percentage when k =2 is :446.37711873455623

# %%
#K=3

#Percentage Error = |Measured Value - True Value| / |True Value| x 100
#Caluclating error percentage of element 3,1 
k3_error_percentage_1 = abs(eA[3][1]-1)/1 *100
print(f"The error percentage of element (3,1) when k =3 is : {k3_error_percentage_1}")
#Caluclating error percentage of element 4,6
k3_error_percentage_2 = abs(eA[4][6]-3)/3 *100
print(f"The error percentage of element (4,6) when k =3 is : {k3_error_percentage_2}")
k3_average_percentage_error = (k3_error_percentage_1 + k3_error_percentage_2)/2
print(f"The average error percentage when k =3 is :{k3_average_percentage_error}")
# Out:
# The error percentage of element (3,1) when k =3 is : 887.5659145399752
# The error percentage of element (4,6) when k =3 is : 11.247865002075203
# The average error percentage when k =3 is :449.4068897710252

# %%
#K=4

#Percentage Error = |Measured Value - True Value| / |True Value| x 100
#Caluclating error percentage of element 3,1 
k4_error_percentage_1 = abs(eA[3][1]-1)/1 *100
print(f"The error percentage of element (3,1) when k =4 is : {k4_error_percentage_1}")
#Caluclating error percentage of element 4,6
k4_error_percentage_2 = abs(eA[4][6]-3)/3 *100
print(f"The error percentage of element (4,6) when k =4 is : {k4_error_percentage_2}")
k4_average_percentage_error = (k4_error_percentage_1 + k4_error_percentage_2)/2
print(f"The average error percentage when k =4 is :{k4_average_percentage_error}")
# Out:
# The error percentage of element (3,1) when k =4 is : 637.3891476331884
# The error percentage of element (4,6) when k =4 is : 18.268698968992783
# The average error percentage when k =4 is :327.8289233010906

# %%
#K=5

#Percentage Error = |Measured Value - True Value| / |True Value| x 100
#Caluclating error percentage of element 3,1 
k5_error_percentage_1 = abs(eA[3][1]-1)/1 *100
print(f"The error percentage of element (3,1) when k =5 is : {k5_error_percentage_1}")
#Caluclating error percentage of element 4,6
k5_error_percentage_2 = abs(eA[4][6]-3)/3 *100
print(f"The error percentage of element (4,6) when k =5 is : {k5_error_percentage_2}")
k5_average_percentage_error = (k5_error_percentage_1 + k5_error_percentage_2)/2
print(f"The average error percentage when k =5 is :{k5_average_percentage_error}")
# Out:
# The error percentage of element (3,1) when k =5 is : 457.7558793107575
# The error percentage of element (4,6) when k =5 is : 2.252914522663933
# The average error percentage when k =5 is :230.00439691671073

# %%
#K=6

#Percentage Error = |Measured Value - True Value| / |True Value| x 100
#Caluclating error percentage of element 3,1 
k6_error_percentage_1 = abs(eA[3][1]-1)/1 *100
print(f"The error percentage of element (3,1) when k =6 is : {k6_error_percentage_1}")
#Caluclating error percentage of element 4,6
k6_error_percentage_2 = abs(eA[4][6]-3)/3 *100
print(f"The error percentage of element (4,6) when k =6 is : {k6_error_percentage_2}")
k6_average_percentage_error = (k6_error_percentage_1 + k6_error_percentage_2)/2
print(f"The average error percentage when k =6 is :{k6_average_percentage_error}")
# Out:
# The error percentage of element (3,1) when k =6 is : 718.7652514561765
# The error percentage of element (4,6) when k =6 is : 2.508281839428654
# The average error percentage when k =6 is :360.6367666478026

# %%
#K=7

#Percentage Error = |Measured Value - True Value| / |True Value| x 100
#Caluclating error percentage of element 3,1 
k7_error_percentage_1 = abs(eA[3][1]-1)/1 *100
print(f"The error percentage of element (3,1) when k =7 is : {k7_error_percentage_1}")
#Caluclating error percentage of element 4,6
k7_error_percentage_2 = abs(eA[4][6]-3)/3 *100
print(f"The error percentage of element (4,6) when k =7 is : {k7_error_percentage_2}")
k7_average_percentage_error = (k7_error_percentage_1 + k7_error_percentage_2)/2
print(f"The average error percentage when k =7 is :{k7_average_percentage_error}")
# Out:
# The error percentage of element (3,1) when k =7 is : 521.8692000881377
# The error percentage of element (4,6) when k =7 is : 11.201368476518159
# The average error percentage when k =7 is :266.53528428232795

# %%
print("The average error percentage is the least when K=1. For other values of K the average error percentage is very high since the predicted value is far from the actual value. ")
# Out:
# The average error percentage is the least when K=1. For other values of K the average error percentage is very high since the predicted value is far from the actual value.
